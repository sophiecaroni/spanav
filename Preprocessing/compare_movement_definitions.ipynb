# %%
from movement_definition import gen_epo_tables, gen_contmov_epos, plot_contmov_epos, count_and_compare_epochs

# %load_ext autoreload
# %autoreload 2

# %%
test = False
save = True
show = True

# %% [markdown]
# # 1. Extract epochs

# %% [markdown]
# ## Load clean raw data

# %%
sids = [
    '02', 
    '03', 
    '04',
    '05',
]
mov_durations_s = [
    3.0, 
    2.5,
    2.0,
]

# %%
gen_epo_tables(sids, mov_durations_s, save=save)

# %%
epos_dict = gen_contmov_epos(sids, mov_durations_s, test=test)

# %%
count_and_compare_epochs(epos_dict)

# %%
plot_contmov_epos(epos_dict, show=show, save=save)
