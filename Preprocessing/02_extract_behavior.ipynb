# %%
from preprocessing.behavior_to_eeg import get_blocks_times, get_trace_df, get_retrieval_df, extract_behavioral_events, extract_eeg_epochs 

# %load_ext autoreload
# %autoreload 2

# %%
test = False
show = True
save = False
auto_mode = False

# %% [markdown]
# # 1. Extract epochs

# %% [markdown]
# ## Load clean raw data

# %%
sid = '02'

# %%
block_times = get_blocks_times(sid)
block_times

# %%
df_trace = get_trace_df(sid)
df_trace

# %%
retrieval_df = get_retrieval_df(sid)
retrieval_df

# %%
beh_events_df = extract_behavioral_events(sid, block_times, retrieval_df, df_trace, save=save)
beh_events_df

# %%
eeg_epochs_table = extract_eeg_epochs(beh_events_df, sid, save=save)
eeg_epochs_table
