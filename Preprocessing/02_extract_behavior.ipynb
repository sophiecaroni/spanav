# %%
from preprocessing.behavior_to_eeg import get_blocks_times, get_trace_df, get_retrieval_df, extract_behavioral_events, define_eeg_epochs 

# %load_ext autoreload
# %autoreload 2

# %%
test = False
show = True
save = True

# %% [markdown]
# # One subject and block at a time
#
# ## 1. Extract epochs
# ### Load clean raw data

# %%
sid = '05'

# %%
block_times = get_blocks_times(sid)
block_times

# %%
df_trace = get_trace_df(sid)
df_trace

# %%
retrieval_df = get_retrieval_df(sid)
retrieval_df

# %%
beh_events_df = extract_behavioral_events(sid, block_times, retrieval_df, df_trace, save=save)
beh_events_df

# %%
eeg_epochs_table = define_eeg_epochs(beh_events_df, sid, save=save)
eeg_epochs_table

# %% [markdown]
# # Multiple subject/blocks at once

# %%
sids = ['02', '03', '04', '05']

# %%
for sid in sids:
    block_times = get_blocks_times(sid)
    df_trace = get_trace_df(sid)
    retrieval_df = get_retrieval_df(sid)
    beh_events_df = extract_behavioral_events(sid, block_times, retrieval_df, df_trace, save=save)
    eeg_epochs_table = define_eeg_epochs(beh_events_df, sid, save=save)
