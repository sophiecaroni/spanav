# %%
from visualization.vis_eeg import plot_evk_by_cat, plot_psd_avg_by_cat
from preprocessing.extract_eeg  import get_raw_to_epoch, get_all_epo_objects
from analysis.process_eeg import compute_psd_by_key

# %load_ext autoreload
# %autoreload 2

# %%
test = False
show = False
save = True
load = False
auto_mode = False

# %% [markdown]
# # 1. Extract epochs

# %%
cids_by_sid = {
    '01': ['RS_pre', 'RS_cTBS', 'SpaNav_task2'],
    '02': ['RS_EO', 'RS_EC', 'task_HF', 'task_iTBS', 'task_cTBS'],
    '03': ['RS_pre_EO', 'block1', 'block2'],
    '04': ['RS_pre_EO', 'RS_pre_EC', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'RS_post_EO', 'RS_post_EC'],
    '05': ['RS_pre_EO', 'RS_pre_EC', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'RS_post_EO', 'RS_post_EC', 'impedances'],
}

# %% [markdown]
# ## Load clean raw data

# %%
sid = '02'
cid = cids_by_sid[sid][4]
cid

# %%
raw_rec = get_raw_to_epoch(sid, cid)

# %%
epos_dict = get_all_epo_objects(raw_rec, sid=sid, cid=cid, save=save, load=load, verbose=False, test=test)
epos_dict

# %% [markdown]
#  # 2. Visualize

# %% [raw]
# %matplotlib qt6
# epo_type = 'MovOn'
# epos_dict[epo_type].plot()

# %% [markdown]
# ## Evoked

# %%
# Plot evoked response (average across epochs)
# %matplotlib inline
plot_evk_by_cat(epos_dict, sid=sid, cid=cid, show=show, save=save)

# %% [markdown]
# ## PSD

# %%
psd_by_rec = compute_psd_by_key(epos_dict)
plot_psd_avg_by_cat(psd_by_rec, sid, cid, show=show, save=save)
