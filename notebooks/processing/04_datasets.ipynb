# %%
from process_eeg import get_psd_df, get_psd_avg_df, get_band_metrics_df

# %load_ext autoreload
# %autoreload 2

# %%
test = False 
load = False
save = True
show = False

# %% [markdown]
# # PSD

# %% [markdown]
# ## Averaging across epochs

# %%
avg_across_epochs=True

# %%
psd_df_log = get_psd_df(load=load, test=test, save=save, avg_across_epochs=avg_across_epochs, log=True)
if show:
    print(psd_df_log)

# %%
psd_df_lin = get_psd_df(load=load, test=test, save=save, avg_across_epochs=avg_across_epochs, log=False)
if show:
    print(psd_df_lin)

# %%
psd_avg_df_log = get_psd_avg_df(load=load, save=save, log=True)
if show:
    print(psd_avg_df_log)

# %%
psd_avg_df_lin = get_psd_avg_df(load=load, save=save, log=False)
if show:
    print(psd_avg_df_lin)

# %% [markdown]
# ## Without averaging across epochs

# %%
psd_df_epo_log = get_psd_df(load=load, test=test, save=save, avg_across_epochs=False, log=True)
if show:
    print(psd_df_epo_log)

# %%
psd_df_epo_lin = get_psd_df(load=load, test=test, save=save, avg_across_epochs=False, log=False)
if show:
    print(psd_df_epo_lin)

# %% [markdown]
# # Oscillations
# ## Bands power, SNR

# %%
osc_df = get_band_metrics_df(load=load, test=test, save=save, avg_across_epochs=True)
if show:
    print(osc_df)

# %%
osc_df_epo = get_band_metrics_df(load=load, test=test, save=save, avg_across_epochs=False)
if show:
    print(osc_df_epo)
