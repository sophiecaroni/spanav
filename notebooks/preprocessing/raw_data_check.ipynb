# %%
from spanav_eeg_utils.io_utils import get_cont_path
from spanav_eeg_utils.plot_utils import get_cont_rec_plot_kwargs
import mne

# %%
sid = '73T10'
task = 'impedances'
acq = 'post1'

# %%
raw_path = get_cont_path('raw', sid, acq, task, server=True)
raw = mne.io.read_raw_brainvision(raw_path, preload=False, verbose=False)

# %%
# %matplotlib qt6
raw.plot(**get_cont_rec_plot_kwargs(raw));
